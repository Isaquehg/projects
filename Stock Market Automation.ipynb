# %% [markdown]
# # Importing a Single Quote

# %%
from pandas_datareader import data as web
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Quote, data_source, start, end
magalu = web.DataReader('MGLU3.SA', data_source = 'yahoo', start = '01/01/2020', end = '01/01/2021')
display(magalu)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-01-02  12.332500  11.927500  12.075000  12.332500  29600800.0  12.029736
# 2020-01-03  12.332500  12.075000  12.125000  12.222500  26737600.0  11.922435
# 2020-01-06  12.327500  11.950000  12.100000  12.232500  27359200.0  11.932189
# 2020-01-07  12.300000  12.125000  12.235000  12.197500  26818800.0  11.898048
# 2020-01-08  12.587500  12.125000  12.155000  12.572500  40007200.0  12.263844
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-22  25.420000  24.850000  25.290001  25.160000  25236200.0  25.115610
# 2020-12-23  25.629999  24.969999  25.250000  24.969999  20558600.0  24.925945
# 2020-12-28  25.330000  24.400000  24.780001  25.250000  23099100.0  25.205452
# 2020-12-29  25.559999  25.020000  25.230000  25.280001  17789700.0  25.235399
# 2020-12-30  25.660000  24.950001  25.370001  24.950001  19188700.0  24.931921
#
# [247 rows x 6 columns]

# %%
#Quotes graphics
magalu['Adj Close'].plot(figsize = (13, 10))#Creating the graphic
plt.show()#Showing it

# %% [markdown]
# # Stock Portifolio with a XLSX File

# %%
companies_df = pd.read_excel('Empresas.xlsx')
display(companies_df)
# Out:
#   Empresas
# 0    ITUB4
# 1    PETR4
# 2    BBDC4
# 3    VALE3

# %%
for company in companies_df['Empresas']:
    quote = web.DataReader(f'{company}.SA', data_source='yahoo', start='01/15/2020', end='06/15/2021')
    display(quote)#table
    quote['Adj Close'].plot(figsize = (13, 10))
    plt.show()#graphic
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-01-15  34.939999  34.400002  34.889999  34.630001  32757500.0  33.199551
# 2020-01-16  35.070000  34.419998  34.900002  34.700001  22857500.0  33.266663
# 2020-01-17  35.299999  34.730000  34.900002  34.939999  19722900.0  33.496765
# 2020-01-20  35.000000  34.160000  34.799999  34.230000  18322200.0  32.816074
# 2020-01-21  34.480000  33.439999  34.009998  33.500000  26878100.0  32.116238
# ...               ...        ...        ...        ...         ...        ...
# 2021-06-09  34.189999  32.419998  32.669998  33.259998  89627300.0  33.226753
# 2021-06-10  33.880001  32.919998  33.599998  33.139999  49940800.0  33.106876
# 2021-06-11  33.150002  32.360001  33.040001  32.750000  23126500.0  32.717270
# 2021-06-14  33.060001  32.360001  32.939999  32.639999  23747300.0  32.607376
# 2021-06-15  32.830002  32.290001  32.759998  32.639999  17613100.0  32.607376
#
# [348 rows x 6 columns]
# ...
